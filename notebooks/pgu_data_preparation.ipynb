# %%
# Python 2 and 3 compatibility
# pip install future
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../train_sets/ПГУ/201706-201707.xlsx')

# %%
df.dropna(subset = ['ID оператора', 'Текст сообщения'], inplace=True)

# %%
df.head()
# Out:
#     ID обращения  ID сообщения Дата открытия обращения  \
# 2          96557       1434917     2017-06-04 20:24:23
# 3          96557       1434918     2017-06-04 20:24:23
# 6          96557       1435875     2017-06-04 20:24:23
# 12         94626       1404010     2017-06-01 00:51:54
# 15         94626       1404016     2017-06-01 00:51:54
#
#    Дата закрытия обращения      Дата сообщения  Время ответа  \
# 2      2017-06-05 10:26:54 2017-06-04 20:25:00           NaN
# 3      2017-06-05 10:26:54 2017-06-04 20:25:12           NaN
# 6      2017-06-05 10:26:54 2017-06-04 23:31:21           NaN
# 12     2017-06-01 01:35:36 2017-06-01 00:52:40           NaN
# 15     2017-06-01 01:35:36 2017-06-01 00:56:47           NaN
#
#                                       Текст сообщения  ID оператора  \
# 2   Ваше обращение получено и будет обработано в б...       18357.0
# 3                                                  вк       18357.0
# 6     Добрый вечер. На портале такой возможности нет.       18271.0
# 12  Здравствуйте! Меня зовут Валентина, я буду рад...       18315.0
# 15  Мне необходимо время на поиск информации, я от...       18315.0
#
#     ID пользователя  Оценка                                  Тип  \
# 2               NaN     NaN                               Вопрос
# 3               NaN     NaN                               Вопрос
# 6               NaN     NaN                               Вопрос
# 12              NaN     4.0  Ошибки получения Электронной услуги
# 15              NaN     4.0  Ошибки получения Электронной услуги
#
#                               Тематика Тема
# 2         Все остальные прочие вопросы  NaN
# 3         Все остальные прочие вопросы  NaN
# 6         Все остальные прочие вопросы  NaN
# 12  Другие услуги (внести комментарий)  NaN
# 15  Другие услуги (внести комментарий)  NaN

# %%
df[df['ID оператора'] <= 18232]['Текст сообщения'].head(100)
# Out:
# 396     Спасибо за отзыв! Сейчас вам будет предложено ...
# 424     Спасибо за отзыв! Сейчас вам будет предложено ...
# 562     Здравствуйте, Оксана! Меня зовут Наталья, я бу...
# 565     В настоящее время статус вашего заявления на п...
# 566     Все статусы и комментарии к заявлениям, которы...
# 567     Рекомендую обратиться в Управление записи акто...
# 568     Вологодская область, Череповец, Советский пр.,...
# 570     К сожалению, у меня нет такой информации. Данн...
# 572     Была рада помочь! У вас остались вопросы по По...
# 574     <img data-code="☺" src="data:image/gif;base64,...
# 740     Здравствуйте, Алла! Меня зовут Наталья, я буду...
# 742     Уточните, пожалуйста, какую услугу вы заказыва...
# 744     К сожалению, в настоящее время по данной услуг...
# 746     Была рада помочь! У вас остались вопросы по По...
# 748     Спасибо за обращение. При возникновении дополн...
# 823     Здравствуйте! Меня зовут Наталья, я буду рада ...
# 827     Если на выбранную вами дату нет свободного вре...
# 829     <img data-code="☺" src="data:image/gif;base64,...
# 831     Спасибо за обращение. При возникновении дополн...
# 886     Был рад помочь! У вас остались вопросы по Порт...
# 888     Спасибо за обращение. При возникновении дополн...
# 892     Здравствуйте! Меня зовут Наталья, чем я могу в...
# 894             Платеж обрабатывается в течение 24 часов.
# 898         Сообщите, пожалуйста, номер транзакции и ФИО.
# 901     Вы только что произвели оплату. В данной ситуа...
# 903     Была рада помочь! У вас остались вопросы по По...
# 906     Изменить данные банковской карты можно только ...
# 910     Вы оплату производили картой, у которой неверн...
# 914     То есть в Личном кабинете у вас данные карты с...
# 917     В этом случае рекомендую уточнить в банке, вып...
#                               ...
# 1414    Здравствуйте! Меня зовут Наталья, чем я могу в...
# 1417    Сообщите, пожалуйста, следующие данные:\r\n- л...
# 1419                          Снилс сообщите, пожалуйста.
# 1422    В настоящее время в Единой системе идентификац...
# 1423    Для удобства работы на Портале госуслуг рекоме...
# 1424    Для входа в подтвержденную учетную запись необ...
# 1426    Была рада помочь! У вас остались вопросы по По...
# 1428    Спасибо за обращение. При возникновении дополн...
# 1445    Здравствуйте, Екатерина! Меня зовут Наталья, я...
# 1447    К сожалению, на Портале госуслуг по данной усл...
# 1449    Да, данная услуга доступна пользователям с под...
# 1450    После регистрации на Портале госуслуг пройти п...
# 1454                                                 Нет.
# 1456    Была рада помочь! У вас остались вопросы по По...
# 1458    Спасибо за обращение. При возникновении дополн...
# 1530    Здравствуйте! Меня зовут Наталья, чем я могу в...
# 1535    Все статусы и комментарии к заявлениям, которы...
# 1536    Обратиться вы можете через Личный кабинет: над...
# 1537    Для получения разъяснений по данному вопросу р...
# 1539    Была рада помочь! У вас остались вопросы по По...
# 1541    Спасибо за обращение. При возникновении дополн...
# 1567    Здравствуйте, Юлия! Меня зовут Наталья, я буду...
# 1570    Сообщите, пожалуйста, следующие данные:\r\n- л...
# 1573    Юлия, у вас в Личном кабинете указаны и мобиль...
# 1576    Со списком адресов ЦО вы можете ознакомиться, ...
# 1577    В этом случае для восстановления доступа необх...
# 1579    Была рада помочь! У вас остались вопросы по По...
# 1581    Спасибо за обращение. При возникновении дополн...
# 1617    Здравствуйте, Дмитрий! Меня зовут Наталья, я б...
# 1619    На Портале госуслуг штраф отобразится в течени...
# Name: Текст сообщения, Length: 100, dtype: object
